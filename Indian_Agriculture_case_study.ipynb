# %% [markdown]
# # Crop Production Analysis -(CASE STUDY)

# %% [markdown]
# _________

# %% [markdown]
# # INDIAN AGRICULTURE SYSTEM

# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the dataset

# %%
df = pd.read_csv('IAS.csv')
df
# Out:
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# 4          4   Uttar Pradesh        JAUNPUR       2016  Rabi
# ...      ...             ...            ...        ...          ...
# 73822  73822           Bihar          BUXAR       2012  Whole Year
# 73823  73823  Madhya Pradesh        RAJGARH       2021  Kharif
# 73824  73824  Madhya Pradesh        RAJGARH       2006  Kharif
# 73825  73825       Rajasthan           TONK       2008  Kharif
# 73826  73826       Jharkhand        KODERMA       2010  Winter
#
#             Crop      Area  Production
# 0          Wheat  81934.00   160425.00
# 1          Onion    257.00      514.00
# 2          Maize    100.00      100.00
# 3      Groundnut   2872.00     4572.00
# 4          Onion    110.00     1290.00
# ...          ...       ...         ...
# 73822      Onion    203.00     1918.00
# 73823      Bajra     12.00       11.00
# 73824  Groundnut   8700.00     9100.00
# 73825      Bajra  34477.00    20137.00
# 73826       Rice  14685.71    18552.95
#
# [73827 rows x 8 columns]

# %% [markdown]
# ### Head function

# %%
df.head(10)
# Out:
#    RowID     State_Name  District_Name  Crop_Year       Season  \
# 0      0          Bihar        NALANDA       2005  Rabi
# 1      1          Assam  KARBI ANGLONG       2019  Whole Year
# 2      2        Gujarat          ANAND       2020  Summer
# 3      3      Karnataka   UTTAR KANNAD       2013  Rabi
# 4      4  Uttar Pradesh        JAUNPUR       2016  Rabi
# 5      5          Assam       MARIGAON       2014  Rabi
# 6      6         Odisha        SONEPUR       2006  Winter
# 7      7      Rajasthan        DHOLPUR       2017  Whole Year
# 8      8      Karnataka        BELGAUM       2018  Whole Year
# 9      9          Bihar         MUNGER       2020  Summer
#
#                 Crop     Area  Production
# 0              Wheat  81934.0    160425.0
# 1              Onion    257.0       514.0
# 2              Maize    100.0       100.0
# 3          Groundnut   2872.0      4572.0
# 4              Onion    110.0      1290.0
# 5  Rapeseed &Mustard   6535.0      2719.0
# 6  Rapeseed &Mustard     91.0         6.0
# 7             Garlic      1.0         1.0
# 8           Coconut     336.0      3212.0
# 9  Moong(Green Gram)    125.0        78.0

# %% [markdown]
# ### Tail Function

# %%
df.tail(10)
# Out:
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 73817  73817     Maharashtra         SANGLI       2021  Kharif
# 73818  73818           Assam       GOALPARA       2016  Rabi
# 73819  73819      Tamil Nadu       ARIYALUR       2017  Whole Year
# 73820  73820   Uttar Pradesh  MUZAFFARNAGAR       2007  Kharif
# 73821  73821     Maharashtra        HINGOLI       2011  Rabi
# 73822  73822           Bihar          BUXAR       2012  Whole Year
# 73823  73823  Madhya Pradesh        RAJGARH       2021  Kharif
# 73824  73824  Madhya Pradesh        RAJGARH       2006  Kharif
# 73825  73825       Rajasthan           TONK       2008  Kharif
# 73826  73826       Jharkhand        KODERMA       2010  Winter
#
#                      Crop      Area  Production
# 73817           Groundnut  25300.00    28300.00
# 73818                Gram    125.00       49.00
# 73819             Tapioca    257.00     8858.00
# 73820                Rice  41988.00   105345.00
# 73821  Other  Rabi pulses    900.00      500.00
# 73822               Onion    203.00     1918.00
# 73823               Bajra     12.00       11.00
# 73824           Groundnut   8700.00     9100.00
# 73825               Bajra  34477.00    20137.00
# 73826                Rice  14685.71    18552.95

# %% [markdown]
# ### Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73827 entries, 0 to 73826
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RowID          73827 non-null  int64
#  1   State_Name     73827 non-null  object
#  2   District_Name  73827 non-null  object
#  3   Crop_Year      73827 non-null  int64
#  4   Season         73827 non-null  object
#  5   Crop           73827 non-null  object
#  6   Area           73827 non-null  float64
#  7   Production     72731 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %% [markdown]
# ### Describing the data

# %%
df.describe()
# Out:
#               RowID     Crop_Year          Area    Production
# count  73827.000000  73827.000000  7.382700e+04  7.273100e+04
# mean   36913.000000   2013.657551  1.218297e+04  6.210320e+05
# std    21312.163499      4.954910  5.348285e+04  1.749756e+07
# min        0.000000   2005.000000  4.000000e-02  0.000000e+00
# 25%    18456.500000   2010.000000  8.100000e+01  8.900000e+01
# 50%    36913.000000   2014.000000  5.900000e+02  7.290000e+02
# 75%    55369.500000   2018.000000  4.500000e+03  7.200000e+03
# max    73826.000000   2023.000000  8.580100e+06  1.125000e+09

# %% [markdown]
# ### Check NULL values

# %%
df.isnull()
# Out:
#        RowID  State_Name  District_Name  Crop_Year  Season   Crop   Area  \
# 0      False       False          False      False   False  False  False
# 1      False       False          False      False   False  False  False
# 2      False       False          False      False   False  False  False
# 3      False       False          False      False   False  False  False
# 4      False       False          False      False   False  False  False
# ...      ...         ...            ...        ...     ...    ...    ...
# 73822  False       False          False      False   False  False  False
# 73823  False       False          False      False   False  False  False
# 73824  False       False          False      False   False  False  False
# 73825  False       False          False      False   False  False  False
# 73826  False       False          False      False   False  False  False
#
#        Production
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 73822       False
# 73823       False
# 73824       False
# 73825       False
# 73826       False
#
# [73827 rows x 8 columns]

# %% [markdown]
# ### Dataset Size

# %%
df.size
# Out:
# 590616

# %% [markdown]
# ### Count Function

# %%
df.count()
# Out:
# RowID            73827
# State_Name       73827
# District_Name    73827
# Crop_Year        73827
# Season           73827
# Crop             73827
# Area             73827
# Production       73827
# dtype: int64

# %% [markdown]
# ### Sum of null values

# %%
df.isnull().sum()
# Out:
# RowID            0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %% [markdown]
# ### Handling missing values

# %%
df['Production'] = df['Production'].fillna(df['Production'].mean())

# %%
df
# Out:
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# 4          4   Uttar Pradesh        JAUNPUR       2016  Rabi
# ...      ...             ...            ...        ...          ...
# 73822  73822           Bihar          BUXAR       2012  Whole Year
# 73823  73823  Madhya Pradesh        RAJGARH       2021  Kharif
# 73824  73824  Madhya Pradesh        RAJGARH       2006  Kharif
# 73825  73825       Rajasthan           TONK       2008  Kharif
# 73826  73826       Jharkhand        KODERMA       2010  Winter
#
#             Crop      Area  Production
# 0          Wheat  81934.00   160425.00
# 1          Onion    257.00      514.00
# 2          Maize    100.00      100.00
# 3      Groundnut   2872.00     4572.00
# 4          Onion    110.00     1290.00
# ...          ...       ...         ...
# 73822      Onion    203.00     1918.00
# 73823      Bajra     12.00       11.00
# 73824  Groundnut   8700.00     9100.00
# 73825      Bajra  34477.00    20137.00
# 73826       Rice  14685.71    18552.95
#
# [73827 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# RowID            0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['RowID', 'State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop',
#        'Area', 'Production'],
#       dtype='object')

# %%
df.shape
# Out:
# (73827, 8)

# %%
plt.boxplot(df['Production'])
plt.show()

# %%
plt.boxplot(df['Area'])
plt.show()

# %%
sns.boxplot(df['Production'])
plt.show()

# %%
sns.boxplot(df['Area'])
plt.show()

# %%
plt.boxplot(df['Crop_Year'])
plt.show()

# %%
x = df['Crop_Year']
y = df['Production']
plt.plot(x, y)
plt.show()

# %%
x = df['Crop_Year']
y = df['Production']
plt.scatter(x, y)
plt.show()

# %%
max_production = df['Production'].max()
crop_name = df[df['Production'] == max_production]['Crop'].values[0]
max_production, crop_name
# Out:
# (np.float64(1125000000.0), 'Coconut ')

# %%
statewise_crop_year_data = df.groupby(['State_Name', 'Crop', 'Crop_Year']).sum()
statewise_crop_year_data.head(10)
# Out:
#                                                     RowID  \
# State_Name                  Crop         Crop_Year
# Andaman and Nicobar Islands Arecanut     2008       14461
#                                          2011       72741
#                                          2012       35328
#                                          2013       43518
#                                          2018       78804
#                             Banana       2008       52870
#                                          2010       44434
#                                          2011       43339
#                             Black pepper 2010       33381
#                                          2011       96143
#
#                                                                              District_Name  \
# State_Name                  Crop         Crop_Year
# Andaman and Nicobar Islands Arecanut     2008             NORTH AND MIDDLE ANDAMANNICOBARS
#                                          2011                               SOUTH ANDAMANS
#                                          2012                               SOUTH ANDAMANS
#                                          2013                               SOUTH ANDAMANS
#                                          2018       NORTH AND MIDDLE ANDAMANSOUTH ANDAMANS
#                             Banana       2008                                     NICOBARS
#                                          2010                                     NICOBARS
#                                          2011                                     NICOBARS
#                             Black pepper 2010                               SOUTH ANDAMANS
#                                          2011                       NICOBARSSOUTH ANDAMANS
#
#                                                                     Season  \
# State_Name                  Crop         Crop_Year
# Andaman and Nicobar Islands Arecanut     2008       Kharif     Kharif
#                                          2011                  Whole Year
#                                          2012                  Whole Year
#                                          2013                  Whole Year
#                                          2018       Rabi       Rabi
#                             Banana       2008                  Whole Year
#                                          2010                  Whole Year
#                                          2011                  Whole Year
#                             Black pepper 2010                  Whole Year
#                                          2011       Whole Year Whole Year
#
#                                                        Area  Production
# State_Name                  Crop         Crop_Year
# Andaman and Nicobar Islands Arecanut     2008       4354.00     7200.00
#                                          2011       3118.00     5182.00
#                                          2012       3160.67     3975.20
#                                          2013       3250.78     3058.46
#                                          2018       3208.00     4190.00
#                             Banana       2008        176.00      641.00
#                                          2010        213.00     1278.00
#                                          2011        266.00     1763.00
#                             Black pepper 2010        487.00      102.50
#                                          2011        572.50      120.23

# %%
statewise_production = df.groupby('State_Name')['Production'].sum().sort_values(ascending=False)
plt.figure(figsize=(25, 20))
statewise_production.plot(kind='bar')
plt.title('State-wise Production')
plt.xlabel('State')
plt.ylabel('Total Production')
plt.show()

# %%
# Get unique values and their counts in the 'Season' column
season_counts = df['Season'].value_counts()
print(season_counts)

# Plot the distribution of the 'Season' column
plt.figure(figsize=(10, 6))
season_counts.plot(kind='bar')
plt.title('Distribution of Seasons')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()
# Out:
# Season
# Kharif         28741
# Rabi           20171
# Whole Year     17158
# Summer          4428
# Winter          1838
# Autumn          1491
# Name: count, dtype: int64

# %% [markdown]
# suggest the crop to be produce as per the season wise

# %%
# Group by 'Season' and 'Crop' and sum the production
season_crop_production = df.groupby(['Season', 'Crop'])['Production'].sum().reset_index()

# Find the crop with the highest production for each season
recommended_crops = season_crop_production.loc[season_crop_production.groupby('Season')['Production'].idxmax()]

# Display the recommended crops for each season
recommended_crops
# Out:
#           Season       Crop    Production
# 13   Autumn            Rice  1.731260e+07
# 89   Kharif       Sugarcane  5.140886e+08
# 166  Rabi             Wheat  3.869581e+08
# 190  Summer            Rice  3.811603e+07
# 226  Whole Year    Coconut   4.180346e+10
# 316  Winter            Rice  1.176271e+08

# %%
x = recommended_crops['Season']
y = recommended_crops['Crop']
plt.figure(figsize=(10, 6))
plt.bar(x, y, color='skyblue')
plt.xlabel('Season')
plt.ylabel('Crop')
plt.title('Recommended Crops for Each Season')
plt.show()

# Display the recommended crops for each season
recommended_crops
# Out:
#           Season       Crop    Production
# 13   Autumn            Rice  1.731260e+07
# 89   Kharif       Sugarcane  5.140886e+08
# 166  Rabi             Wheat  3.869581e+08
# 190  Summer            Rice  3.811603e+07
# 226  Whole Year    Coconut   4.180346e+10
# 316  Winter            Rice  1.176271e+08

# %%
# Scatter plot to visualize the relationship between Area and Production
plt.figure(figsize=(10, 6))
plt.scatter(df['Area'], df['Production'], alpha=0.5)
plt.title('Relationship between Area and Production')
plt.xlabel('Area')
plt.ylabel('Production')
plt.show()

# %% [markdown]
# Max Production = kerala
# least production  = chandigadh

# %% [markdown]
# ### Aggregating data by year

# %%
# Aggregating data by year
yearly_production = df.groupby("Crop_Year")["Production"].sum()
yearly_area = df.groupby("Crop_Year")["Area"].sum()

# Plotting trends
fig, ax1 = plt.subplots(figsize=(12, 6))
ax1.set_xlabel("Year")
ax1.set_ylabel("Total Production (Million Tons)", color="tab:blue")
ax1.plot(yearly_production.index, yearly_production / 1e6, label="Total Production", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.set_ylabel("Total Area (Million Hectares)", color="tab:green")
ax2.plot(yearly_area.index, yearly_area / 1e6, label="Total Area", color="tab:green", linestyle="dashed")
ax2.tick_params(axis="y", labelcolor="tab:green")

fig.suptitle("Yearly Trends in Crop Production and Cultivated Area")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion: Yearly Crop Production Trends
# * Crop production and cultivated area have increased over time.
# * Some fluctuations indicate possible external influences like climate, policy changes, or market demand.

# %%
# Grouping data by Season and finding the most produced crop for each season
seasonal_crop_production = df.groupby(["Season", "Crop"])["Production"].sum().reset_index()

# Identifying the top crop for each season
top_crops_per_season = seasonal_crop_production.loc[seasonal_crop_production.groupby("Season")["Production"].idxmax()]

# Display results
top_crops_per_season
# Out:
#           Season       Crop    Production
# 13   Autumn            Rice  1.731260e+07
# 89   Kharif       Sugarcane  5.140886e+08
# 166  Rabi             Wheat  3.869581e+08
# 190  Summer            Rice  3.811603e+07
# 226  Whole Year    Coconut   4.180346e+10
# 316  Winter            Rice  1.176271e+08

# %% [markdown]
# ## Conclusion: Best Crops for Each Season
# * Rice is the most commonly grown crop across multiple seasons (Autumn, Summer, Winter).
# * Sugarcane is the top crop in Kharif, and Wheat in Rabi.
# * Coconut is grown throughout the year, making it the most productive crop overall.

# %%
# Aggregating total production by state
statewise_production = df.groupby("State_Name")["Production"].sum().sort_values(ascending=False).head(10)

# Plotting state-wise production distribution
plt.figure(figsize=(12, 6))
sns.barplot(x=statewise_production.values, y=statewise_production.index, palette="coolwarm")
plt.title("Top 10 States by Total Crop Production")
plt.xlabel("Total Production (Billion Tons)")
plt.ylabel("State")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()
# Out:
# C:\Users\Vedant  Shigwan\AppData\Local\Temp\ipykernel_11312\3731818888.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=statewise_production.values, y=statewise_production.index, palette="coolwarm")

# %% [markdown]
# ## Conclusion: State-wise Crop Production
# * Some states dominate total crop production.
# * Likely high producers: Uttar Pradesh, Maharashtra, and Tamil Nadu.
# * Regional specialization exists, with some states focusing on specific high-yield crops.

# %%
# Scatter plot to visualize correlation between Area and Production
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Area"], y=df["Production"], alpha=0.5)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Area (Hectares)")
plt.ylabel("Production (Metric Tons)")
plt.title("Correlation Between Area and Production")
plt.grid(True, which="both", linestyle="--", alpha=0.7)
plt.show()

# Compute correlation coefficient
correlation = df["Area"].corr(df["Production"])
correlation
# Out:
# np.float64(0.040989338894996986)

# %% [markdown]
# ## Conclusion: Correlation Between Cultivated Area and Production
# * Weak correlation (≈ 0.04) suggests that more land does not always mean higher production.
# * Possible reasons:
# 1. Some crops have a high yield per hectare (e.g., Coconut, Sugarcane).
# 2. Inefficient land use or varying soil fertility.
# 3. Advanced farming techniques improving yield efficiency.

# %%
# Boxplot to detect production outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["Production"], showfliers=True, color="salmon")
plt.xscale("log")
plt.title("Outlier Detection in Crop Production")
plt.xlabel("Production (Metric Tons, Log Scale)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# Identifying extreme outliers (top 0.1% highest production values)
outlier_threshold = df["Production"].quantile(0.999)
outliers = df[df["Production"] > outlier_threshold]

# Displaying top outliers
outliers.sort_values(by="Production", ascending=False).head(10)
# Out:
#        RowID State_Name District_Name  Crop_Year       Season      Crop  \
# 47698  47698     Kerala    MALAPPURAM       2020  Whole Year   Coconut
# 51889  51889     Kerala    MALAPPURAM       2021  Whole Year   Coconut
# 71369  71369     Kerala    MALAPPURAM       2012  Whole Year   Coconut
# 24990  24990     Kerala     KOZHIKODE       2010  Whole Year   Coconut
# 42202  42202     Kerala     KOZHIKODE       2020  Whole Year   Coconut
# 46168  46168     Kerala     KOZHIKODE       2017  Whole Year   Coconut
# 14698  14698     Kerala     KOZHIKODE       2012  Whole Year   Coconut
# 30490  30490     Kerala     KOZHIKODE       2015  Whole Year   Coconut
# 70820  70820     Kerala     KOZHIKODE       2013  Whole Year   Coconut
# 45917  45917     Kerala     KOZHIKODE       2014  Whole Year   Coconut
#
#            Area    Production
# 47698  102417.0  1.125000e+09
# 51889  105481.0  9.350000e+08
# 71369  113162.0  9.000000e+08
# 24990  127402.0  8.880000e+08
# 42202  124819.0  8.820000e+08
# 46168  119166.0  8.680000e+08
# 14698  129865.0  8.540000e+08
# 30490  122929.0  8.510000e+08
# 70820  129500.0  8.450000e+08
# 45917  129401.0  8.240000e+08

# %% [markdown]
# ## Conclusion: Outlier Detection in Crop Production
# * Extreme outliers found in Coconut production, mainly in Kerala (Malappuram & Kozhikode).
# * Highest production recorded: 1.125 billion metric tons in 2020 (Kerala).
# * Coconut has exceptionally high yield, making it a strong candidate for large-scale production & export.

# %% [markdown]
# ## Final Summary of Analysis
#  ✅ **Coconut** dominates crop production, followed by **Sugarcane, Rice, and Wheat**.
#  ✅ **Kharif (Sugarcane)** and **Rabi (Wheat)** are the most productive seasons.
#  ✅ **Kerala** leads in high-yielding **coconut** production.
#  ✅ **Production and land area have weak correlation**, meaning **yield efficiency** matters.
#  ✅ **Outliers confirm Kerala’s dominance** in coconut production.
